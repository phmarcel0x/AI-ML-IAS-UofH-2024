# %% [markdown]
# ### Preliminary Data Analysis for Coursework 1

# %%
# Impoort libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import timedelta

# %%
# Load data
data_path = '../IAS_DATA/6com2007-3.csv'
data = pd.read_csv(data_path)

# print the first 5 rows of the data
print("Data Head")
print(data.head())  

# print the data info (data types, non-null values, memory usage)
print("\nData Info")
print(data.info())  

# print the data statistics (count, mean, std, min, 25%, 50%, 75%, max)
print("\nData Describe")
print(data.describe())
# Out:
# Data Head
#          Date   Time  CO2_room  Relative_humidity_room  Lighting_room  \
# 0  13/03/2012  11:45   221.920                 42.4150        113.520
# 1  13/03/2012  12:00   220.363                 42.2453        113.605
# 2  13/03/2012  12:15   218.933                 42.2267        113.600
# 3  13/03/2012  12:30   217.045                 42.0987        113.344
# 4  13/03/2012  12:45   216.080                 42.0686        113.034
#
#    Meteo_Rain  Meteo_Sun_dusk  Meteo_Wind  Meteo_Sun_light_in_west_facade  \
# 0         0.0         623.360     1.42625                               0
# 1         0.0         623.211     1.59200                               0
# 2         0.0         622.656     1.89133                               0
# 3         0.0         622.571     1.82800                               0
# 4         0.0         622.400     2.36071                               0
#
#    Meteo_Sun_light_in_east_facade  ...  Meteo_Sun_irradiance  \
# 0                         9690.24  ...               758.880
# 1                        11022.00  ...               762.069
# 2                        13960.50  ...               766.251
# 3                        18511.20  ...               766.037
# 4                        26349.00  ...               762.743
#
#    Outdoor_relative_humidity_Sensor  Day_of_the_week  Occupancy 1  \
# 0                           48.3750              2.0            1
# 1                           47.8080              2.0            1
# 2                           47.4320              2.0            1
# 3                           47.0240              2.0            1
# 4                           45.4743              2.0            1
#
#    Occupancy 2  Occupancy 3  Indoor_temperature_room  Humidity  Outside temp  \
# 0            0            0                  17.8275   42.4150         17.00
# 1            0            0                  18.1207   42.2453         17.21
# 2            0            0                  18.4367   42.2267         17.46
# 3            0            0                  18.7513   42.0987         17.66
# 4            0            0                  19.0414   42.0686         17.87
#
#    Satisfaction
# 0   93.38399375
# 1   94.52955651
# 2   95.61276811
# 3   96.46542331
# 4   97.09823604
#
# [5 rows x 22 columns]
#
# Data Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2764 entries, 0 to 2763
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Date                              2764 non-null   object
#  1   Time                              2764 non-null   object
#  2   CO2_room                          2764 non-null   float64
#  3   Relative_humidity_room            2764 non-null   float64
#  4   Lighting_room                     2764 non-null   float64
#  5   Meteo_Rain                        2764 non-null   float64
#  6   Meteo_Sun_dusk                    2764 non-null   float64
#  7   Meteo_Wind                        2764 non-null   float64
#  8   Meteo_Sun_light_in_west_facade    2764 non-null   int64
#  9   Meteo_Sun_light_in_east_facade    2764 non-null   float64
#  10  Meteo_Sun_light_in_south_facade   2764 non-null   float64
#  11  Meteo_Sun_light_in_north_facade   2764 non-null   float64
#  12  Meteo_Sun_irradiance              2764 non-null   float64
#  13  Outdoor_relative_humidity_Sensor  2764 non-null   float64
#  14  Day_of_the_week                   2764 non-null   float64
#  15  Occupancy 1                       2764 non-null   int64
#  16  Occupancy 2                       2764 non-null   int64
#  17  Occupancy 3                       2764 non-null   int64
#  18  Indoor_temperature_room           2764 non-null   float64
#  19  Humidity                          2764 non-null   float64
#  20  Outside temp                      2762 non-null   float64
#  21  Satisfaction                      2759 non-null   object
# dtypes: float64(15), int64(4), object(3)
# memory usage: 475.2+ KB
# None
#
# Data Describe
#           CO2_room  Relative_humidity_room  Lighting_room   Meteo_Rain  \
# count  2764.000000             2764.000000    2764.000000  2764.000000
# mean    211.065844               47.321220      40.732571     0.047033
# std      28.469144                7.557795      42.326087     0.206705
# min     188.907000               29.594700      11.328000     0.000000
# 25%     202.682750               42.531325      13.265300     0.000000
# 50%     209.408000               47.534700      17.690000     0.000000
# 75%     213.218750               52.685975      52.057350     0.000000
# max     609.237000               62.594700     162.965000     1.000000
#
#        Meteo_Sun_dusk   Meteo_Wind  Meteo_Sun_light_in_west_facade  \
# count     2764.000000  2764.000000                          2764.0
# mean       325.369289     1.108531                             0.0
# std        305.062614     1.161283                             0.0
# min          0.606667     0.000000                             0.0
# 25%          0.650000     0.094833                             0.0
# 50%        611.797000     0.659000                             0.0
# 75%        619.210750     1.971497                             0.0
# max        624.960000     6.321330                             0.0
#
#        Meteo_Sun_light_in_east_facade  Meteo_Sun_light_in_south_facade  \
# count                     2764.000000                      2764.000000
# mean                     14936.617682                     12248.000148
# std                      25964.049455                     21758.550527
# min                          0.000000                         0.000000
# 25%                          0.000000                         0.000000
# 50%                          0.000000                         0.000000
# 75%                      15088.000000                     11131.275000
# max                      95278.400000                     85535.400000
#
#        Meteo_Sun_light_in_north_facade  Meteo_Sun_irradiance  \
# count                      2764.000000           2764.000000
# mean                      22047.525813            215.010017
# std                       32709.387051            297.234046
# min                           0.000000             -4.164670
# 25%                           0.000000             -3.381330
# 50%                           0.000000              3.922000
# 75%                       38736.575000            435.434500
# max                       95704.400000           1028.270000
#
#        Outdoor_relative_humidity_Sensor  Day_of_the_week  Occupancy 1  \
# count                       2764.000000      2764.000000  2764.000000
# mean                          55.981988         3.954438     0.531838
# std                           13.019610         1.991799     0.499076
# min                           22.260700         1.000000     0.000000
# 25%                           46.430675         2.000000     0.000000
# 50%                           57.477350         4.000000     1.000000
# 75%                           65.649325         6.000000     1.000000
# max                           83.805300         7.000000     1.000000
#
#        Occupancy 2  Occupancy 3  Indoor_temperature_room     Humidity  \
# count  2764.000000  2764.000000              2764.000000  2764.000000
# mean      0.325253     0.001809                18.824852    47.321220
# std       0.468554     0.042501                 2.821178     7.557795
# min       0.000000     0.000000                11.076000    29.594700
# 25%       0.000000     0.000000                17.060350    42.531325
# 50%       0.000000     0.000000                19.021000    47.534700
# 75%       1.000000     0.000000                20.828700    52.685975
# max       1.000000     1.000000                24.944000    62.594700
#
#        Outside temp
# count   2762.000000
# mean      19.006593
# std        3.787042
# min       12.360000
# 25%       17.150000
# 50%       19.000000
# 75%       20.867500
# max      166.170000

# %%
# Check for missing values
print(data.isnull().sum())
# Out:
# Date                                0
# Time                                0
# CO2_room                            0
# Relative_humidity_room              0
# Lighting_room                       0
# Meteo_Rain                          0
# Meteo_Sun_dusk                      0
# Meteo_Wind                          0
# Meteo_Sun_light_in_west_facade      0
# Meteo_Sun_light_in_east_facade      0
# Meteo_Sun_light_in_south_facade     0
# Meteo_Sun_light_in_north_facade     0
# Meteo_Sun_irradiance                0
# Outdoor_relative_humidity_Sensor    0
# Day_of_the_week                     0
# Occupancy 1                         0
# Occupancy 2                         0
# Occupancy 3                         0
# Indoor_temperature_room             0
# Humidity                            0
# Outside temp                        2
# Satisfaction                        5
# dtype: int64

# %%
# Drop missing values
data_clean = data.dropna()
print(data_clean.isnull().sum())
# Out:
# Date                                0
# Time                                0
# CO2_room                            0
# Relative_humidity_room              0
# Lighting_room                       0
# Meteo_Rain                          0
# Meteo_Sun_dusk                      0
# Meteo_Wind                          0
# Meteo_Sun_light_in_west_facade      0
# Meteo_Sun_light_in_east_facade      0
# Meteo_Sun_light_in_south_facade     0
# Meteo_Sun_light_in_north_facade     0
# Meteo_Sun_irradiance                0
# Outdoor_relative_humidity_Sensor    0
# Day_of_the_week                     0
# Occupancy 1                         0
# Occupancy 2                         0
# Occupancy 3                         0
# Indoor_temperature_room             0
# Humidity                            0
# Outside temp                        0
# Satisfaction                        0
# dtype: int64
